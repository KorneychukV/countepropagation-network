# %%
import numpy as np
import pandas as pd
import csv
import random
import math

# %% [markdown]
# # Инициализация

# %%
# количество признаков входного слоя
feature_count = 4

# %% [markdown]
# # Считывание данных из файла и их подготовка

# %%
df = pd.read_csv('data/titanik.csv', sep=',')

drop_column = ['SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin']

# подготовленный датасет
train_data = []
# датасет для тестирования
test_data = []

classes = df['Survived'].unique()

df['Sex'] = df['Sex'].replace(['male','female'], [0, 1])
df['Embarked'] = df['Embarked'].fillna(('S'))
df['Embarked'] = df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
df['Pclass'] = df['Pclass'].fillna(np.mean(df['Pclass']))
df['Age'] = df['Age'].fillna(df['Age'].median())

for i in range(len(df)) : 

    features = np.zeros((feature_count))
    features[0] = df.loc[i, 'Sex']
    features[1] = df.loc[i, 'Embarked']
    features[2] = df.loc[i, 'Pclass']
    features[3] = df.loc[i, 'Age']
    
    
    # Нормализация входного вектора
    norm_features = np.zeros((feature_count))
    for j in range(len(features)):
        sum = 0 
        for k in range(len(features)):
            sum += features[k] ** 2
        norm_features[j] = features[j] / math.sqrt(sum)
    
    temp_data = dict(name = df.loc[i, 'Name'], 
                     features = norm_features, 
                     result = np.where(classes == df.loc[i, "Survived"])[0].item(0))
    
    if (len(train_data) / len(df)) < 0.9:
        train_data.append(temp_data)
    else:
        test_data.append(temp_data)

# %% [markdown]
# # Обучение

# %% [markdown]
# ## Кохонен

# %%
def getKohonenWinnerIndex(x, neuron_counts, w, s):
    result = 0
    max_net = -1
    for i in range(neuron_counts):
        net = 0
        for j in range(len(x)):
            net += x[j] * w[j][i] * s[i]
        if (net > max_net):
            result = i
            max_net = net
    return result

# %%
# скорость обучения слоя Кохонена
theta = 0.7
# скорость обучения слоя Гроссберга
beta = 0.1
#количество нейронов выходного слоя (слоя Гроссберга) = количество проффессий 
grossberg_neuron_counts = len(classes)
# количество нейронов кохонена
kohonen_neuron_count = 16
# штрафы кластеров
s_w = np.ones((kohonen_neuron_count))
# количество эпох
epoch_count = 50

#инициализация начальных весов слоя Кохонена kohonen_w[x][y]
# x - индекс нейрона входного слоя
# y - индекс нейрона слоя Кохонена
kohonen_w = np.zeros((feature_count, kohonen_neuron_count))
for i in range(feature_count):
    for j in range(kohonen_neuron_count):
        kohonen_w[i, j] = random.uniform(0, 1)
        
# Инициализация начальных весов слоя Гроссберга grossberg_w[x][y]
# x - индекс нейрона слоя Кохонена
# y - индекс нейрона слоя Гроссберга
grossberg_w = np.zeros((kohonen_neuron_count, grossberg_neuron_counts))
for i in range(kohonen_neuron_count):
    for j in range(grossberg_neuron_counts):
        grossberg_w[i, j] = random.uniform(0, 1)
        
step = epoch_count* len(train_data)
# Обучение на подготовленном датасете
while step >= 0:
    
    man = train_data[random.randint(0, len(train_data) - 1)]
    
    # Определение нейрона победителя
    winner_index = getKohonenWinnerIndex(man['features'], kohonen_neuron_count, kohonen_w, s_w)
    s_w[winner_index] *= 0.999
    
    # Корректировка весов нейрона победителя на слое Кохонена
    for i in range(feature_count):
        kohonen_w[i][winner_index] += theta * (man['features'][i] - kohonen_w[i][winner_index])
    
    # Корректировка весов для нейронов слоя Гроссберга, соединенных с нейроном победителем слоя Кохонена
    for i in range(grossberg_neuron_counts):
        if i == man['result']:
            grossberg_w[winner_index][i] += beta * (1 - grossberg_w[winner_index][i])
        else:
            grossberg_w[winner_index][i] += beta * (0 - grossberg_w[winner_index][i])
    
    # Изменение скорости обучения
    theta, beta = theta - (theta * 0.00007), beta - (beta * 0.00007)  
    step -= 1
print(theta)
print(beta)
print(s_w)
# Out:
# 0.04226300355960048
# 0.006037571937085852
# [0.08092299 0.08092299 0.08092299 0.08092299 0.08084207 0.08084207
#  0.08092299 0.08092299 0.08231114 0.08899191 0.08092299 0.08092299
#  0.08092299 0.08084207 0.08084207 0.08084207]

# %% [markdown]
# # Тестирование

# %%
accuracy = 0
for man in test_data:
    
    print('Класс: ' + str(classes[man['result']]))
    print('ФИО: ' + man['name'])
    print('Результаты нейросети:')
    
    # Определение нейрона победителя
    winner_index = getKohonenWinnerIndex(man['features'], kohonen_neuron_count, kohonen_w, s_w)
    best_result = 0.0
    best_index = 0

    for i in range(grossberg_neuron_counts):
        if (grossberg_w[winner_index][i] > best_result):
            best_result = grossberg_w[winner_index][i]
            best_indexe = i
        print(str(classes[i]) + ': ' + str(grossberg_w[winner_index][i] * 100) + '%')
    
    if (man['result'] == best_index):
        accuracy += 1
    print('--------------------------------------------------')
print ('Точность: ' + str((accuracy / len(test_data)) * 100) + '%')
# Out:
# Класс: 1
# ФИО: Carter, Master. William Thornton II
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Thomas, Master. Assad Alexander
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 1
# ФИО: Hedman, Mr. Oskar Arvid
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Johansson, Mr. Karl Johan
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 0
# ФИО: Andrews, Mr. Thomas Jr
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Pettersson, Miss. Ellen Natalia
# Результаты нейросети:
# 0: 81.23864052527891%
# 1: 18.761359474721058%
# --------------------------------------------------
# Класс: 0
# ФИО: Meyer, Mr. August
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Chambers, Mrs. Norman Campbell (Bertha Griggs)
# Результаты нейросети:
# 0: 33.95797212696969%
# 1: 66.04202787303032%
# --------------------------------------------------
# Класс: 0
# ФИО: Alexander, Mr. William
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Lester, Mr. James
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Slemen, Mr. Richard James
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Andersson, Miss. Ebba Iris Alfrida
# Результаты нейросети:
# 0: 63.67166859518926%
# 1: 36.328331404810754%
# --------------------------------------------------
# Класс: 0
# ФИО: Tomlin, Mr. Ernest Portage
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 0
# ФИО: Fry, Mr. Richard
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Heininen, Miss. Wendla Maria
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Mallet, Mr. Albert
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Holm, Mr. John Fredrik Alexander
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Skoog, Master. Karl Thorsten
# Результаты нейросети:
# 0: 63.67166859518926%
# 1: 36.328331404810754%
# --------------------------------------------------
# Класс: 1
# ФИО: Hays, Mrs. Charles Melville (Clara Jennings Gregg)
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Lulic, Mr. Nikola
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Reuchlin, Jonkheer. John George
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Moor, Mrs. (Beila)
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 0
# ФИО: Panula, Master. Urho Abraham
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 0
# ФИО: Flynn, Mr. John
# Результаты нейросети:
# 0: 49.36914998068554%
# 1: 50.63085001931458%
# --------------------------------------------------
# Класс: 0
# ФИО: Lam, Mr. Len
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Mallet, Master. Andre
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 1
# ФИО: McCormack, Mr. Thomas Joseph
# Результаты нейросети:
# 0: 49.36914998068554%
# 1: 50.63085001931458%
# --------------------------------------------------
# Класс: 1
# ФИО: Stone, Mrs. George Nelson (Martha Evelyn)
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Yasbeck, Mrs. Antoni (Selini Alexander)
# Результаты нейросети:
# 0: 63.67166859518926%
# 1: 36.328331404810754%
# --------------------------------------------------
# Класс: 1
# ФИО: Richards, Master. George Sibley
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 0
# ФИО: Saad, Mr. Amin
# Результаты нейросети:
# 0: 62.92452329909639%
# 1: 37.0754767009036%
# --------------------------------------------------
# Класс: 0
# ФИО: Augustsson, Mr. Albert
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Allum, Mr. Owen George
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Compton, Miss. Sara Rebecca
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 0
# ФИО: Pasic, Mr. Jakob
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Sirota, Mr. Maurice
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Chip, Mr. Chang
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Marechal, Mr. Pierre
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 0
# ФИО: Alhomaki, Mr. Ilmari Rudolf
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Mudd, Mr. Thomas Charles
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Serepeca, Miss. Augusta
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 0
# ФИО: Lemberopolous, Mr. Peter L
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Culumovic, Mr. Jeso
# Результаты нейросети:
# 0: 81.23864052527891%
# 1: 18.761359474721058%
# --------------------------------------------------
# Класс: 0
# ФИО: Abbing, Mr. Anthony
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Sage, Mr. Douglas Bullen
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Markoff, Mr. Marin
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Harper, Rev. John
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 0
# ФИО: Andersson, Master. Sigvard Harald Elias
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 0
# ФИО: Svensson, Mr. Johan
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Boulos, Miss. Nourelain
# Результаты нейросети:
# 0: 63.67166859518926%
# 1: 36.328331404810754%
# --------------------------------------------------
# Класс: 1
# ФИО: Lines, Miss. Mary Conover
# Результаты нейросети:
# 0: 34.004951203135164%
# 1: 65.99504879686489%
# --------------------------------------------------
# Класс: 0
# ФИО: Carter, Mrs. Ernest Courtenay (Lilian Hughes)
# Результаты нейросети:
# 0: 33.95797212696969%
# 1: 66.04202787303032%
# --------------------------------------------------
# Класс: 1
# ФИО: Aks, Mrs. Sam (Leah Rosen)
# Результаты нейросети:
# 0: 81.23864052527891%
# 1: 18.761359474721058%
# --------------------------------------------------
# Класс: 1
# ФИО: Wick, Mrs. George Dennick (Mary Hitchcock)
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Daly, Mr. Peter Denis
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 1
# ФИО: Baclini, Mrs. Solomon (Latifa Qurban)
# Результаты нейросети:
# 0: 62.92452329909639%
# 1: 37.0754767009036%
# --------------------------------------------------
# Класс: 0
# ФИО: Razi, Mr. Raihed
# Результаты нейросети:
# 0: 62.92452329909639%
# 1: 37.0754767009036%
# --------------------------------------------------
# Класс: 0
# ФИО: Hansen, Mr. Claus Peter
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Giles, Mr. Frederick Edward
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 1
# ФИО: Swift, Mrs. Frederick Joel (Margaret Welles Barron)
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Sage, Miss. Dorothy Edith "Dolly"
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 0
# ФИО: Gill, Mr. John William
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Bystrom, Mrs. (Karolina)
# Результаты нейросети:
# 0: 33.95797212696969%
# 1: 66.04202787303032%
# --------------------------------------------------
# Класс: 1
# ФИО: Duran y More, Miss. Asuncion
# Результаты нейросети:
# 0: 34.004951203135164%
# 1: 65.99504879686489%
# --------------------------------------------------
# Класс: 0
# ФИО: Roebling, Mr. Washington Augustus II
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: van Melkebeke, Mr. Philemon
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Johnson, Master. Harold Theodor
# Результаты нейросети:
# 0: 48.27861096878577%
# 1: 51.721389031214215%
# --------------------------------------------------
# Класс: 0
# ФИО: Balkic, Mr. Cerin
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Carlsson, Mr. Frans Olof
# Результаты нейросети:
# 0: 58.95045809629753%
# 1: 41.04954190370239%
# --------------------------------------------------
# Класс: 0
# ФИО: Vander Cruyssen, Mr. Victor
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Abelson, Mrs. Samuel (Hannah Wizosky)
# Результаты нейросети:
# 0: 34.004951203135164%
# 1: 65.99504879686489%
# --------------------------------------------------
# Класс: 1
# ФИО: Najib, Miss. Adele Kiamie "Jane"
# Результаты нейросети:
# 0: 63.67166859518926%
# 1: 36.328331404810754%
# --------------------------------------------------
# Класс: 0
# ФИО: Gustafsson, Mr. Alfred Ossian
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Petroff, Mr. Nedelio
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Laleff, Mr. Kristo
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 1
# ФИО: Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 1
# ФИО: Shelley, Mrs. William (Imanita Parrish Hall)
# Результаты нейросети:
# 0: 34.004951203135164%
# 1: 65.99504879686489%
# --------------------------------------------------
# Класс: 0
# ФИО: Markun, Mr. Johann
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Dahlberg, Miss. Gerda Ulrika
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Banfield, Mr. Frederick James
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 0
# ФИО: Sutehall, Mr. Henry Jr
# Результаты нейросети:
# 0: 86.77296782009594%
# 1: 13.227032179904064%
# --------------------------------------------------
# Класс: 0
# ФИО: Rice, Mrs. William (Margaret Norton)
# Результаты нейросети:
# 0: 62.92452329909639%
# 1: 37.0754767009036%
# --------------------------------------------------
# Класс: 0
# ФИО: Montvila, Rev. Juozas
# Результаты нейросети:
# 0: 79.58418272231297%
# 1: 20.415817277687033%
# --------------------------------------------------
# Класс: 1
# ФИО: Graham, Miss. Margaret Edith
# Результаты нейросети:
# 0: 34.004951203135164%
# 1: 65.99504879686489%
# --------------------------------------------------
# Класс: 0
# ФИО: Johnston, Miss. Catherine Helen "Carrie"
# Результаты нейросети:
# 0: 77.79728915174199%
# 1: 22.202710848257993%
# --------------------------------------------------
# Класс: 1
# ФИО: Behr, Mr. Karl Howell
# Результаты нейросети:
# 0: 54.4955152964119%
# 1: 45.50448470358816%
# --------------------------------------------------
# Класс: 0
# ФИО: Dooley, Mr. Patrick
# Результаты нейросети:
# 0: 62.92452329909639%
# 1: 37.0754767009036%
# --------------------------------------------------
# Точность: 62.92134831460674%
