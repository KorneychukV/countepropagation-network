# %%
import numpy as np
import pandas as pd
import csv
import random
import math
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Считывание данных из файла и их подготовка

# %%
def getBdate(bdate):
  return datetime.strptime(bdate, '%d.%m.%Y').month

# %% [markdown]
# ## Студенты

# %%
# количество признаков входного слоя
feature_count = 2

# подготовленный датасет
train_data = []
# датасет для тестирования
test_data = []

drop_column = ['№п/п', 'Основание поступления']
gender_dict = {'Мужской': 1,'Женский': 0}

df = pd.read_csv('data/input.csv', sep=',')
df.drop(drop_column, axis = 1, inplace = True)

# переводим пол в числовой формат, т. к. это будет один из признаков
df['Пол'].replace(gender_dict, inplace = True) 

# приводим баллы по ЕГЭ к диапозону от 0 до 1
df.astype({'Баллы ЕГЭ': 'float'}).dtypes
df['Баллы ЕГЭ'] /= 100

# fios = df['ФИО'].unique()
# subjects = df['Предметы ЕГЭ'].unique()
# cities = df['Населенный пункт по прописке'].unique()
# schools = df['Учебное заведение'].unique()
# classes = df['Специальность/направление'].unique()

# Смотрим только для информатики
fios = df.loc[df['Предметы ЕГЭ'] == 'Информатика и ИКТ', 'ФИО']
classes = df.loc[df['Предметы ЕГЭ'] == 'Информатика и ИКТ', 'Специальность/направление'].unique()
subjects = df.loc[df['Специальность/направление'].isin(classes), 'Предметы ЕГЭ'].unique()
subjects = subjects[:2]

for el in fios:
    student = df[df['ФИО'] == el]
    features = np.zeros((feature_count))
    for i in range(len(subjects)):
        res = student.loc[student['Предметы ЕГЭ'] == subjects[i], 'Баллы ЕГЭ'].values
        features[i] = res[0] if len(res) else 0
#     features[5] = student.iloc[0]['Пол']
#     features[6] = getBdate(student.iloc[0]['Дата рождения']) / 12
    
#     city_index = np.where(cities == student.iloc[0]['Населенный пункт по прописке'])[0]
#     features[7] = 0 if len(city_index) == 0 else city_index[0]/len(cities)
    
#     school_number = np.where(schools == student.iloc[0]['Учебное заведение'])[0]
#     features[8] = 0 if len(school_number) == 0 else school_number[0]/len(schools)
    
    # Нормализация входного вектора x/length(vector)
    norm_features = np.zeros((feature_count))
    for i in range(len(features)):
        sum = 0 
        for j in range(len(features)):
            sum += features[j] ** 2
        norm_features[i] = features[i] / math.sqrt(sum)
#     norm_features = (features * features.mean()) / features.std()
    
    res = np.zeros((len(classes)))
    res[np.where(classes == student.iloc[0]['Специальность/направление'])[0][0]] = 1
    
    # Нормализованные
    temp_data = dict(fio = el, features = norm_features, result = res)
    # Не нормализованные
#     temp_data = dict(fio = el, features = features, result = res)
    
    # 90% - train, 10% - test
    if (len(train_data) / len(fios)) < 0.9:
        train_data.append(temp_data)
    else:
        test_data.append(temp_data)
        #train_data.append(temp_data)

# %%
subjects[:2]
# Out:
# array(['Математика', 'Информатика и ИКТ'], dtype=object)

# %% [markdown]
# ## Титаник

# %%
# df = pd.read_csv('data/titanik.csv', sep=',')

# # количество признаков входного слоя
# feature_count = 5
# drop_column = ['Parch', 'Ticket', 'Fare', 'Cabin']

# # подготовленный датасет
# train_data = []
# # датасет для тестирования
# test_data = []

# classes = df['Survived'].unique()

# df['Sex'] = df['Sex'].replace(['male','female'], [0, 1])
# df['Embarked'] = df['Embarked'].fillna(('S'))
# df['Embarked'] = df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# df['Pclass'] = df['Pclass'].fillna(np.mean(df['Pclass']))
# df['Pclass'] = df['Pclass']/max(df['Pclass'])

# df['Age'] = df['Age'].fillna(df['Age'].median())
# df['Age'] = df['Age']/max(df['Age'])

# df['SibSp'] = df['SibSp'].fillna(df['SibSp'].median())
# df['SibSp'] = df['SibSp']/max(df['SibSp'])


# vectors = []

# for i in range(len(df)) : 

#     features = np.zeros((feature_count))
#     features[0] = df.loc[i, 'Sex']
#     features[1] = df.loc[i, 'Embarked']
#     features[2] = df.loc[i, 'Pclass']
#     features[3] = df.loc[i, 'Age']
#     features[4] = df.loc[i, 'SibSp']
    
#     # Нормализация входного вектора
# #     norm_features = np.zeros((feature_count))
# #     for j in range(len(features)):
# #         sum = 0 
# #         for k in range(len(features)):
# #             sum += features[k] ** 2
# #         norm_features[j] = features[j] / math.sqrt(sum)
    
# #     norm_features_old = (features * features.mean()) / features.std()
#     norm_features = features/np.linalg.norm(features)
    
#     # Нормализованные    
#     temp_data = dict(name = df.loc[i, 'Name'], 
#                      features = norm_features, 
#                      result = np.where(classes == df.loc[i, "Survived"])[0])
    
#     # Не нормализованные    
# #     temp_data = dict(name = df.loc[i, 'Name'], 
# #                      features = features, 
# #                      result = np.where(classes == df.loc[i, "Survived"])[0])
    
#     if (len(train_data) / len(df)) < 0.9:
#         train_data.append(temp_data)
#     else:
#         train_data.append(temp_data)
#         test_data.append(temp_data)

# %% [markdown]
# ## Ирис

# %%
# # количество признаков входного слоя
# feature_count = 4

# df = pd.read_csv('data/iris.csv', sep=',')

# # подготовленный датасет
# train_data = []
# # датасет для тестирования
# test_data = []

# classes = df["variety"].unique()

# df = df.sample(frac=1).reset_index(drop=True)

# for i in range(len(df)) : 

#     features = np.zeros((feature_count))
#     features[0] = df.loc[i, "sepal.length"]
#     features[1] = df.loc[i, "sepal.width"]
#     features[2] = df.loc[i, "petal.length"]
#     features[3] = df.loc[i, "petal.width"]
    
#     # Нормализация входного вектора
#     norm_features = features/np.linalg.norm(features)
    
#     res = np.zeros((len(classes)))
#     res[np.where(classes == df.loc[i, "variety"])[0].item(0)] = 1
    
#     temp_data = dict(name = str(i), 
#                      features = norm_features, 
#                      result = res)
    
#     if (len(train_data) / len(df)) < 0.9:
#         train_data.append(temp_data)
#         test_data.append(temp_data)
#     else:
# #         train_data.append(temp_data)
#         test_data.append(temp_data)

# %% [markdown]
# # Обучение

# %% [markdown]
# ## Кохонен

# %%
def getKohonenWinnerIndex(x, neuron_counts, w, s):
    result = 0
    max_net = -1
    for i in range(neuron_counts):
        net = 0
        for j in range(len(x)):
            net += x[j] * w[j][i] * s[i]
        if (net > max_net):
            result = i
            max_net = net
    return result

def mse(pred, actual):
    return np.square(np.subtract(actual,pred)).mean()

# %%
# скорость обучения слоя Кохонена
# 0.5 для студентов
# 0.7 для титаника 
# 0.4 для ирисок 
theta = 0.7
# скорость обучения слоя Гроссберга
# 0.1 для студентов
# 0.1 для титаника  
# 0.1 для ирисок
beta = 0.1
# количество нейронов кохонена
# 200 для студентов
# 20 для титаника  
# 30 для ирисок
kohonen_neuron_count = 200
# количество эпох
# 100 для студентов
# 200 для титаника
# 70 для ирисок
epoch_count = 200

# %%
#количество нейронов выходного слоя (слоя Гроссберга) = количество проффессий 
grossberg_neuron_counts = len(train_data[0]['result'])
# штрафы кластеров
s_w = np.ones((kohonen_neuron_count))

#инициализация начальных весов слоя Кохонена kohonen_w[x][y]
# x - индекс нейрона входного слоя
# y - индекс нейрона слоя Кохонена
kohonen_w = np.random.uniform(0, 1, (len(train_data[0]['features']), kohonen_neuron_count))

# Инициализация начальных весов слоя Гроссберга grossberg_w[x][y]
# x - индекс нейрона слоя Кохонена
# y - индекс нейрона слоя Гроссберга
grossberg_w = np.random.uniform(0, 1, (kohonen_neuron_count, grossberg_neuron_counts))

element_result = np.zeros((grossberg_neuron_counts))
epoch_error = np.zeros((len(train_data)))
train_err = np.zeros((epoch_count))
        
# Обучение на подготовленном датасете
for ep in range(epoch_count):
#     print('------------------')
#     print('Epoch ' + str(ep))
    for el in range(len(train_data)):

        # train_el = train_data[random.randint(0, len(train_data) - 1)]
        train_el = train_data[el]

        # Определение нейрона победителя
        winner_index = getKohonenWinnerIndex(train_el['features'], kohonen_neuron_count, kohonen_w, s_w)

        # Увеличиваем штраф, уменьшая его коэффициент
        # Для студентов 0,7
        s_w[winner_index] *= 0.7

        # Корректировка весов нейрона победителя на слое Кохонена
        for i in range(feature_count):
            kohonen_w[i][winner_index] += theta * (train_el['features'][i] - kohonen_w[i][winner_index])

        # Корректировка весов для нейронов слоя Гроссберга, соединенных с нейроном победителем слоя Кохонена
        for i in range(grossberg_neuron_counts):
            if train_el['result'][i] == 1:
                grossberg_w[winner_index][i] += beta * (1 - grossberg_w[winner_index][i])
            else:
                grossberg_w[winner_index][i] += beta * (0 - grossberg_w[winner_index][i])
            
            element_result[i] = grossberg_w[winner_index][i]
        
        epoch_error[el] = mse(element_result, train_el['result'])

        # Изменение скорости обучения
        # для студентов theta - (theta * 0.0001), beta - (beta * 0.0001) 
        # для титаника theta - (theta * 0.08), beta - (beta * 0.05)
        # для ирисок  theta - (theta * 0.008), beta - (beta * 0.0005)
    theta, beta = theta - (theta * 0.01), beta - (beta * 0.01) 
    
    train_err[ep] = epoch_error.mean()

print(theta)
print(beta)
# Out:
# 0.09378577240057334
# 0.013397967485796207

# %% [markdown]
# # Тестирование

# %% [markdown]
# ## Тестирование студентов

# %% [markdown]
# ## Тестирование на всех специальностей

# %%
# accuracy = 0
# s_w = np.ones((kohonen_neuron_count))

# for student in test_data:
#     print('ФИО: ' + student['fio'])
#     print('Поступил на специальность: ' + classes[np.where(student['result'] == 1)[0][0]])
#     print('Результаты нейросети:')
#     # Определение нейрона победителя
#     winner_index = getKohonenWinnerIndex(student['features'], kohonen_neuron_count, kohonen_w, s_w)
#     best_results = [0.0, 0.0, 0.0]
#     best_indexes = [0, 1, 2]
#     max_res = 0.0
#     max_index = 0
#     for i in range(grossberg_neuron_counts):
        
#         if (grossberg_w[winner_index][i] > best_results[0]):
#             best_results[2] = best_results[1]
#             best_results[1] = best_results[0]
#             best_results[0] = grossberg_w[winner_index][i]
#             best_indexes[2] = best_indexes[1]
#             best_indexes[1] = best_indexes[0]
#             best_indexes[0] = i
#         elif (grossberg_w[winner_index][i] > best_results[1]):
#             best_results[2] = best_results[1]
#             best_results[1] = grossberg_w[winner_index][i]
#             best_indexes[2] = best_indexes[1]
#             best_indexes[1] = i
#         elif (grossberg_w[winner_index][i] > best_results[2]):
#             best_results[2] = grossberg_w[winner_index][i]
#             best_indexes[2] = i
        
#     print(classes[best_indexes[0]] + ': ' + str(grossberg_w[winner_index][best_indexes[0]] * 100) + '%')
#     print(classes[best_indexes[1]] + ': ' + str(grossberg_w[winner_index][best_indexes[1]] * 100) + '%')
#     print(classes[best_indexes[2]] + ': ' + str(grossberg_w[winner_index][best_indexes[2]] * 100) + '%')
#     print('-------------------')
#     print(classes[np.where(student['result'] == 1)[0][0]] + ': ' + str(grossberg_w[winner_index][np.where(student['result'] == 1)[0][0]] * 100) + '%')
    
#     if (np.where(student['result'] == 1)[0][0] in best_indexes):
#         accuracy += 1
#     print('--------------------------------------------------')
# print ('Точность: ' + str((accuracy / len(test_data)) * 100) + '%')

# %%
# # Света
# #инф 64
# #русский 70
# #математика 79

# # Егор
# # 54 физика
# # 70 математика
# # 98 русский

# tester = np.array([0.70, 0.0, 0.98, 0.54, 0.0, 1.0, 0.25, 0.05555, 0.06796])
# norm_features = (tester * tester.mean()) / tester.std()
# norm_features

# winner_index = getKohonenWinnerIndex(norm_features, kohonen_neuron_count, kohonen_w, s_w)

# best_results = [0.0, 0.0, 0.0]
# best_indexes = [0, 1, 2]

# for i in range(grossberg_neuron_counts):
#     if (grossberg_w[winner_index][i] > best_results[0]):
#         best_results[2] = best_results[1]
#         best_results[1] = best_results[0]
#         best_results[0] = grossberg_w[winner_index][i]
#         best_indexes[2] = best_indexes[1]
#         best_indexes[1] = best_indexes[0]
#         best_indexes[0] = i
#     elif (grossberg_w[winner_index][i] > best_results[1]):
#         best_results[2] = best_results[1]
#         best_results[1] = grossberg_w[winner_index][i]
#         best_indexes[2] = best_indexes[1]
#         best_indexes[1] = i
#     elif (grossberg_w[winner_index][i] > best_results[2]):
#         best_results[2] = grossberg_w[winner_index][i]
#         best_indexes[2] = i
        
# print(classes[best_indexes[0]] + ': ' + str(grossberg_w[winner_index][best_indexes[0]] * 100) + '%')
# print(classes[best_indexes[1]] + ': ' + str(grossberg_w[winner_index][best_indexes[1]] * 100) + '%')
# print(classes[best_indexes[2]] + ': ' + str(grossberg_w[winner_index][best_indexes[2]] * 100) + '%')

# %%
accuracy = 0
#s_w = np.ones((kohonen_neuron_count))

inf = np.array([])
prog = np.array([])
econ = np.array([])

for student in test_data:
    print('ФИО: ' + student['fio'])
    print('Поступил на специальность: ' + classes[np.where(student['result'] == 1)[0][0]])
    print('Результаты нейросети:')
    # Определение нейрона победителя
    winner_index = getKohonenWinnerIndex(student['features'], kohonen_neuron_count, kohonen_w, s_w)
    print(winner_index)
    max_res = 0.0
    max_index = 0
    for i in range(grossberg_neuron_counts):
        if (grossberg_w[winner_index][i] > max_res):
            max_index = i
            max_res = grossberg_w[winner_index][i]
        
    print(classes[0] + ': ' + str(grossberg_w[winner_index][0] * 100) + '%')
    print(classes[1] + ': ' + str(grossberg_w[winner_index][1] * 100) + '%')
    print(classes[2] + ': ' + str(grossberg_w[winner_index][2] * 100) + '%')
    print('-------------------')
    print(classes[np.where(student['result'] == 1)[0][0]] + ': ' + str(grossberg_w[winner_index][np.where(student['result'] == 1)[0][0]] * 100) + '%')
    
    if np.where(student['result'] == 1)[0][0] == 0:
        inf = np.append(inf, [winner_index], axis=0)
    elif np.where(student['result'] == 1)[0][0] == 1:
        econ = np.append(econ, [winner_index], axis=0)
    elif np.where(student['result'] == 1)[0][0] == 2:
        prog = np.append(prog, [winner_index], axis=0)
    
    if (np.where(student['result'] == 1)[0][0] == max_index):
        accuracy += 1
    print('--------------------------------------------------')
print ('Точность: ' + str((accuracy / len(test_data)) * 100) + '%')
# Out:
# ФИО: Федотов Денис Владимирович
# Поступил на специальность: Программная инженерия
# Результаты нейросети:
# 162
# Информатика и вычислительная техника: 99.89314916374747%
# Прикладная информатика (в экономике): 0.02701037918406713%
# Программная инженерия: 0.04668298428094156%
# -------------------
# Программная инженерия: 0.04668298428094156%
# --------------------------------------------------
# ФИО: Фролов Михаил Сергеевич
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 30
# Информатика и вычислительная техника: 94.18783502162147%
# Прикладная информатика (в экономике): 5.8319566147271145%
# Программная инженерия: 0.09725302918098035%
# -------------------
# Информатика и вычислительная техника: 94.18783502162147%
# --------------------------------------------------
# ФИО: Хисамиев Харис Мурадович
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 100
# Информатика и вычислительная техника: 99.82661769490336%
# Прикладная информатика (в экономике): 0.12429505426317043%
# Программная инженерия: 0.11605019209223157%
# -------------------
# Информатика и вычислительная техника: 99.82661769490336%
# --------------------------------------------------
# ФИО: Хлесткова Мария Александровна
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 105
# Информатика и вычислительная техника: 99.80122797235722%
# Прикладная информатика (в экономике): 0.21076540021080598%
# Программная инженерия: 0.16116403627098724%
# -------------------
# Информатика и вычислительная техника: 99.80122797235722%
# --------------------------------------------------
# ФИО: Хромов Никита Владимирович
# Поступил на специальность: Прикладная информатика (в экономике)
# Результаты нейросети:
# 11
# Информатика и вычислительная техника: 99.70782603838877%
# Прикладная информатика (в экономике): 0.2589236798441872%
# Программная инженерия: 0.24008829978699062%
# -------------------
# Прикладная информатика (в экономике): 0.2589236798441872%
# --------------------------------------------------
# ФИО: Чистенькин Евгений Владиславович
# Поступил на специальность: Программная инженерия
# Результаты нейросети:
# 101
# Информатика и вычислительная техника: 89.13730026526065%
# Прикладная информатика (в экономике): 0.024060792490112566%
# Программная инженерия: 10.76408910000778%
# -------------------
# Программная инженерия: 10.76408910000778%
# --------------------------------------------------
# ФИО: Чунаков Михаил Алексеевич
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 94
# Информатика и вычислительная техника: 0.23900151561972055%
# Прикладная информатика (в экономике): 0.08795186929797119%
# Программная инженерия: 99.77381435517498%
# -------------------
# Информатика и вычислительная техника: 0.23900151561972055%
# --------------------------------------------------
# ФИО: Шабанов Руслан Романович
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 2
# Информатика и вычислительная техника: 99.60938809393811%
# Прикладная информатика (в экономике): 0.20075770984395738%
# Программная инженерия: 0.21356488822952113%
# -------------------
# Информатика и вычислительная техника: 99.60938809393811%
# --------------------------------------------------
# ФИО: Шадрин Олег Павлович
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 100
# Информатика и вычислительная техника: 99.82661769490336%
# Прикладная информатика (в экономике): 0.12429505426317043%
# Программная инженерия: 0.11605019209223157%
# -------------------
# Информатика и вычислительная техника: 99.82661769490336%
# --------------------------------------------------
# ФИО: Шевелев Александр Михайлович
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 46
# Информатика и вычислительная техника: 99.80778538619097%
# Прикладная информатика (в экономике): 0.17728858130790073%
# Программная инженерия: 0.060028878409162954%
# -------------------
# Информатика и вычислительная техника: 99.80778538619097%
# --------------------------------------------------
# ФИО: Щербаков Даниил Павлович
# Поступил на специальность: Прикладная информатика (в экономике)
# Результаты нейросети:
# 76
# Информатика и вычислительная техника: 0.11010713165584994%
# Прикладная информатика (в экономике): 99.71038407328669%
# Программная инженерия: 0.17035850562316504%
# -------------------
# Прикладная информатика (в экономике): 99.71038407328669%
# --------------------------------------------------
# ФИО: Ювченко Давид Андреевич
# Поступил на специальность: Программная инженерия
# Результаты нейросети:
# 184
# Информатика и вычислительная техника: 0.09147687520888244%
# Прикладная информатика (в экономике): 99.84340462982786%
# Программная инженерия: 0.08046602863289565%
# -------------------
# Программная инженерия: 0.08046602863289565%
# --------------------------------------------------
# ФИО: Юсупов Кирилл Олегович
# Поступил на специальность: Информатика и вычислительная техника
# Результаты нейросети:
# 7
# Информатика и вычислительная техника: 99.76866948856787%
# Прикладная информатика (в экономике): 0.18730600466687683%
# Программная инженерия: 0.061824139081612516%
# -------------------
# Информатика и вычислительная техника: 99.76866948856787%
# --------------------------------------------------
# ФИО: Яблокова Полина Николаевна
# Поступил на специальность: Прикладная информатика (в экономике)
# Результаты нейросети:
# 195
# Информатика и вычислительная техника: 0.12027235994893347%
# Прикладная информатика (в экономике): 0.13950708630062675%
# Программная инженерия: 99.77344584929456%
# -------------------
# Прикладная информатика (в экономике): 0.13950708630062675%
# --------------------------------------------------
# ФИО: Янюк Дарья Андреевна
# Поступил на специальность: Программная инженерия
# Результаты нейросети:
# 4
# Информатика и вычислительная техника: 64.9515489340389%
# Прикладная информатика (в экономике): 7.200209292162432%
# Программная инженерия: 27.954123369849626%
# -------------------
# Программная инженерия: 27.954123369849626%
# --------------------------------------------------
# Точность: 53.333333333333336%

# %%
print(np.unique(inf))
print(np.unique(econ))
print(np.unique(prog))
# Out:
# [  2.   7.  30.  46.  94. 100. 105.]
# [ 11.  76. 195.]
# [  4. 101. 162. 184.]

# %% [markdown]
# ## Тестирование титаника

# %%
# #s_w = np.ones((kohonen_neuron_count))

# right = 0
# pred = 0
# res = np.zeros((kohonen_neuron_count))
# for test_el in test_data:
#     print('Имя: ' + test_el['name'])
#     print('Остался в живых: ' + ('Да' if test_el['result'] == 1 else 'Нет'))
#     print('Результаты нейросети:')
#     # Определение нейрона победителя
#     winner_index = getKohonenWinnerIndex(test_el['features'], kohonen_neuron_count, kohonen_w, s_w)
#     print(winner_index)
#     res[winner_index] += 1
#     result = grossberg_w[winner_index][0] * 100
#     print(str(result) + '%')
#     if result > 50:
#         pred = 1
#     if (test_el['result'][0] == pred):
#         right += 1
#     print('--------------------------------------------------')
# print ('Точность: ' + str((right / len(test_data)) * 100) + '%')

# %%
# print(res)
# print(len(train_err))
# plt.plot(train_err)
# plt.ylabel('MSE')
# plt.show()

# %% [markdown]
# ## Тестирование ирисок

# %%
# #s_w = np.ones((kohonen_neuron_count))

# right = 0
# pred = 0
# res = np.zeros((kohonen_neuron_count))
# for test_el in test_data:
#     print('Индекс: ' + test_el['name'])
#     print('Это вид: ' + classes[np.where(test_el["result"] == 1)[0][0]])
#     print('Результаты нейросети:')
#     # Определение нейрона победителя
#     winner_index = getKohonenWinnerIndex(test_el['features'], kohonen_neuron_count, kohonen_w, s_w)
#     print(winner_index)
#     res[winner_index] += 1
#     temp = 0
#     max_res = grossberg_w[winner_index][0] * 100
#     max_index = 0
#     for i in range(grossberg_neuron_counts):
#         result = grossberg_w[winner_index][i] * 100
#         if max_res < result:
#             max_res, max_index = result, i
#         print(classes[i] + ': ' + str(result) + '%')
     
#     if np.where(test_el['result'] == 1)[0][0] == max_index:
#         print('right')
#         right += 1
#     print('--------------------------------------------------')
# print ('Точность: ' + str((right / len(test_data)) * 100) + '%')

# %%
print(res)
print(len(train_err))
plt.plot(train_err)
plt.ylabel('MSE')
plt.show()
# Out:
# [0. 0. 1.]
# 200
